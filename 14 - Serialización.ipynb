# %% [markdown]
# # Serialización

# %% [markdown]
# ## Introducción
#
# El concepto de **serialización** es la transformación de datos a un formato exportable que se puede almacenar para recuperar posteriormente o para compartir entre distintos programas.
#
# La información se puede **serializar** en texto plano, que son legibles como archivos de texto, o en archivos binarios que son codificados y solamente legibles por software que entiende dicha codificación.
#
# Además, atendiendo a la estructura de datos, se puede almacenar información en dos tipos de estructuras, **planas** o **anidadas**:
#
# - **Estructura plana**: cada objeto se representa en una línea, similar a una **lista** o una **tupla**.
# - **Estructura anidada**: cada objeto se representa como clave/valor, similar a los diccionarios.

# %% [markdown]
# ## Como texto plano

# %% [markdown]
# ### CSV
#
# El formato **csv** (*comma-separated values*) es el formato de **estructura plana** más común de serialización de **estructura plana**. Cada valor se representa en una misma línea, separados por coma. El punto débil de este formato es que no es un formato estandarizado, es decir, no atiende al formato de los campos que se representan en él. Las **cadenas de texto**, por ejemplo, no tienen porque venir delimitadas por comillas.

# %%
import csv
import os

ruta_al_archivo = os.path.join("examples", "files", "listado-estaciones-completo.csv")

def lector_csv(ruta):
    with open(ruta, "r", encoding="utf8") as archivo:
        lector = csv.reader(archivo, quotechar='"')

        for linea in lector:
            yield linea
            
generador_csv = lector_csv(ruta_al_archivo)

for i in range(1, 5):
    print(next(generador_csv))
# Out:
# ['CÓDIGO', 'DESCRIPCION', 'LATITUD', 'LONGITUD', 'DIRECCIÓN', 'C.P.', 'POBLACION', 'PROVINCIA', 'PAIS', 'CERCANIAS', 'FEVE']
# ['11208', 'VITORIA/GASTEIZ', '42,8415284', '-2,6726651', 'PLAZUELA DE LA ESTACION, 1', '01005', 'Vitoria-Gasteiz', 'Araba/Álava', 'España', 'NO', 'NO']
# ['11212', 'AGURAIN/SALVATIERRA DE ALAVA', '42,8464369', '-2,3892266', 'TREBIÑO KALEA, S/N', '01200', 'Salvatierra/Agurain', 'Araba/Álava', 'España', 'NO', 'NO']
# ['11213', 'ARAIA', '42,8694713', '-2,3068018', 'CALLE ESTACION FERROCARRIL, S/N', '01208', 'Arraia-Maeztu', 'Araba/Álava', 'España', 'NO', 'NO']

# %% [markdown]
# ### JSON
#
# **JSON** (*JavaScript Object Notation*) es de los formatos mas comunes para intercambio de datos en internet, y el formato mas extendido en [API REST](https://www.redhat.com/es/topics/api/what-is-a-rest-api). Se trata de un formato clave-valor, por tanto **estructura anidada**, y es idéntico a los **diccionarios** en **python**. En este formato si se especifican tipos de datos, se pueden representar **números**, **cadenas de texto**, **booleanos**, **valor nulo**, **listas** y otros **diccionarios**.

# %%
import json
import os

ruta_al_archivo = os.path.join("examples", "files", "listado-estaciones-completo.json")

with open(ruta_al_archivo, "r") as f:
    estaciones = json.load(f)

print(estaciones)
# Out:
# {'11208': {'descripcion': 'vitoria/gasteiz', 'latitud': '42,8415284', 'longitud': '-2,6726651', 'dirección': 'plazuela de la estacion, 1', 'c.p.': '01005', 'poblacion': 'vitoria-gasteiz', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11212': {'descripcion': 'agurain/salvatierra de alava', 'latitud': '42,8464369', 'longitud': '-2,3892266', 'dirección': 'trebiño kalea, s/n', 'c.p.': '01200', 'poblacion': 'salvatierra/agurain', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11213': {'descripcion': 'araia', 'latitud': '42,8694713', 'longitud': '-2,3068018', 'dirección': 'calle estacion ferrocarril, s/n', 'c.p.': '01208', 'poblacion': 'arraia-maeztu', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11203': {'descripcion': 'manzanos', 'latitud': '42,7428754', 'longitud': '-2,8675305', 'dirección': 'rio zadorra kalea, s/n', 'c.p.': '01220', 'poblacion': 'ribera baja/erribera beitia', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11205': {'descripcion': 'nanclares-langraiz', 'latitud': '42,8162344', 'longitud': '-2,8049335', 'dirección': 'la estacion kalez, s/n', 'c.p.': '01230', 'poblacion': 'iruña oka/iruña de oca', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11210': {'descripcion': 'alegria-dulantzi', 'latitud': '42,8488289', 'longitud': '-2,5145516', 'dirección': 'calle estacion ferrocarril, s/n', 'c.p.': '01240', 'poblacion': 'alegría-dulantzi', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '13104': {'descripcion': 'santa cruz de llodio', 'latitud': '43,132826', 'longitud': '-2,969878', 'dirección': 'poligono indrustrialdea, s/n', 'c.p.': '01400', 'poblacion': 'laudio/llodio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13106': {'descripcion': 'llodio', 'latitud': '43,14236', 'longitud': '-2,960654', 'dirección': 'jose matia kalea, s/n', 'c.p.': '01400', 'poblacion': 'laudio/llodio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13107': {'descripcion': 'areta', 'latitud': '43,145122', 'longitud': '-2,94342', 'dirección': 'estacion bidea, 4', 'c.p.': '01400', 'poblacion': 'laudio/llodio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13103': {'descripcion': 'luiaondo', 'latitud': '43,093579', 'longitud': '-2,999671', 'dirección': 'oloste kalea, s/n', 'c.p.': '01408', 'poblacion': 'ayala/aiara', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13101': {'descripcion': 'amurrio', 'latitud': '43,049155', 'longitud': '-3,001748', 'dirección': 'kalea dionisio aldama, 15', 'c.p.': '01470', 'poblacion': 'amurrio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13102': {'descripcion': 'salbio', 'latitud': '43,074147', 'longitud': '-2,999397', 'dirección': 'urrieta kalea, s/n', 'c.p.': '01470', 'poblacion': 'amurrio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13116': {'descripcion': 'iñarratxu', 'latitud': '43,035792', 'longitud': '-3,003896', 'dirección': 'saratxo entitatea, s/n', 'c.p.': '01470', 'poblacion': 'amurrio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13121': {'descripcion': 'amurrio iparralde', 'latitud': '43,05771', 'longitud': '-2,996331', 'dirección': 'juan de aranoa kalea, s/n', 'c.p.': '01470', 'poblacion': 'amurrio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '60600': {'descripcion': 'albacete los llanos', 'latitud': '39,0002979', 'longitud': '-1,8487356', 'dirección': 'calle federico garcia lorca, 1', 'c.p.': '02001', 'poblacion': 'albacete', 'provincia': 'albacete', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '60507': {'descripcion': 'la gineta', 'latitud': '39,1117194', 'longitud': '-2,000316', 'dirección': 'calle santa ana, ...

# %% [markdown]
# ### YAML
#
# Es un formato idéntico a **JSON** pero su uso está mas popularizado en **archivos de configuración** de aplicaciones, como por ejemplo [Docker Compose](https://docs.docker.com/compose/). La principal diferencia es que **YAML** delimita los diferentes niveles con **identación** en lugar de utilizando llaves, pero puede reperesentar también **números**, **cadenas de texto**, **booleanos**, **valor nulo**, **listas** y otros **diccionarios**. También se trata de una **estructura anidada**. No viene en la librería estándar, hay que instalar el paquete `pyyaml`

# %%
import yaml
import os

ruta_al_archivo = os.path.join("examples", "files", "listado-estaciones-completo.yaml")

with open(ruta_al_archivo, "r") as f:
    estaciones = yaml.load(f, Loader=yaml.FullLoader)

print(estaciones)
# Out:
# {'01003': {'c.p.': '41600', 'cercanias': 'no', 'descripcion': 'arahal', 'dirección': 'calle virgen de los dolores, s/n', 'feve': 'no', 'latitud': '37,268141', 'longitud': '-5,5484006', 'pais': 'españa', 'poblacion': 'arahal', 'provincia': 'sevilla'}, '01005': {'c.p.': '41620', 'cercanias': 'no', 'descripcion': 'marchena', 'dirección': 'avenida maestro santos ruano, 8', 'feve': 'no', 'latitud': '37,3342501', 'longitud': '-5,4254295', 'pais': 'españa', 'poblacion': 'marchena', 'provincia': 'sevilla'}, '01007': {'c.p.': '41640', 'cercanias': 'no', 'descripcion': 'osuna', 'dirección': 'avenida estacion ferrocarril, s/n', 'feve': 'no', 'latitud': '37,2337769', 'longitud': '-5,1148398', 'pais': 'españa', 'poblacion': 'osuna', 'provincia': 'sevilla'}, '01009': {'c.p.': '41566', 'cercanias': 'no', 'descripcion': 'pedrera', 'dirección': 'calle manuel aranda, 3', 'feve': 'no', 'latitud': '37,2223527', 'longitud': '-4,893696', 'pais': 'españa', 'poblacion': 'pedrera', 'provincia': 'sevilla'}, '02002': {'c.p.': '14500', 'cercanias': 'no', 'descripcion': 'puente genil-herrera', 'dirección': 'carretera a-318 - km. 9 - entre los pueblos de puente genil (córdoba) y herrera (sevilla)', 'feve': 'no', 'latitud': '37,3597116', 'longitud': '-4,8221946', 'pais': 'españa', 'poblacion': 'puente genil', 'provincia': 'córdoba'}, '02003': {'c.p.': '29540', 'cercanias': 'no', 'descripcion': 'antequera-santa ana', 'dirección': 'carretera ma-5406 - estacion ferrocarril, s/n', 'feve': 'no', 'latitud': '37,0702806', 'longitud': '-4,7190304', 'pais': 'españa', 'poblacion': 'antequera', 'provincia': 'málaga'}, '03001': {'c.p.': '23620', 'cercanias': 'no', 'descripcion': 'mengibar-artichuela', 'dirección': 'calle camino estacion ferrocarril, s/n', 'feve': 'no', 'latitud': '37,9778433', 'longitud': '-3,8019294', 'pais': 'españa', 'poblacion': 'mengíbar', 'provincia': 'jaén'}, '03100': {'c.p.': '23007', 'cercanias': 'no', 'descripcion': 'jaen', 'dirección': 'plaza de jaen por la paz, 1', 'feve': 'no', 'latitud': '37,7800495', 'longitud': '-3,7908847', 'pais': 'españa', 'poblacion': 'jaén', 'provincia': 'jaén'}, '03208': {'c.p.': '16004', 'cercanias': 'no', 'descripcion': 'cuenca fernando zobel', 'dirección': 'avenida cerro de la estrella, s/n - n-320 - circunvalacion de cuenca', 'feve': 'no', 'latitud': '40,0352819', 'longitud': '-2,1441378', 'pais': 'españa', 'poblacion': 'cuenca', 'provincia': 'cuenca'}, '03213': {'c.p.': '46340', 'cercanias': 'no', 'descripcion': 'requena-utiel', 'dirección': 'autovia a3 - salida 285', 'feve': 'no', 'latitud': '39,5217269', 'longitud': '-1,1346669', 'pais': 'españa', 'poblacion': 'requena', 'provincia': 'valencia/valéncia'}, '03216': {'c.p.': '46007', 'cercanias': 'no', 'descripcion': 'valencia joaquin sorolla', 'dirección': 'calle san vicente martir, 171', 'feve': 'no', 'latitud': '39,4600028', 'longitud': '-0,3813222', 'pais': 'españa', 'poblacion': 'valencia', 'provincia': 'valencia/valéncia'}, '03309': {'c.p.': '03400', 'cercanias': 'no', 'descripcion': 'villena alta velocidad', 'dirección': 'partida de san juan, 182', 'feve': 'no', 'latitud': '38,5846082', 'longitud': '-0,8734737', 'pais': 'españa', 'poblacion': 'villena', 'provincia': 'alicante/alacant'}, '03410': {'c.p.': '03006', 'cercanias': 'no', 'descripcion': 'elx alta velocidad', 'dirección': 'calle nieve, 0', 'feve': 'no', 'latitud': '38,24625', 'longitud': '-0,76566', 'pais': 'españa', 'poblacion': 'elche/elx', 'provincia': 'alicante/alacant'}, '04007': {'c.p.': '19000', 'cercanias': 'no', 'descripcion': 'guadalajara-yebes', 'dirección': 'carretera n-320 sacedon-cuenca, km 268', 'feve': 'no', 'latitud': '40,5879523', 'longitud': '-3,1249541', 'pais': 'españa', 'poblacion': 'guadalajara', 'provincia': 'guadalajara'}, '04040': {'c.p.': '50011', 'cercanias': 'si', 'descripcion': 'zaragoza-delicias', 'dirección': 'calle rioja, 33', 'feve': 'no', 'latitud': '41,6587744', 'longitud': '-0,9112734', 'pais': 'españa', 'poblacion': 'zaragoza', 'provincia': 'zaragoza'}, '0 ...

# %% [markdown]
# ## Como archivos binarios

# %% [markdown]
# ### Pickle
#
# Es un formato binario propio de **python** y se puede utilizar para persistir datos en este lenguaje, pero no se recomienda para intercambio de datos entre diferentes lenguajes.
#
# Es también una **estructura anidada** y permite representar **números**, **cadenas de texto**, **booleanos**, **valor nulo**, **listas**, **tuplas**, **sets** y otros **diccionarios**.

# %%
import pickle
import os

ruta_al_archivo = os.path.join("examples", "files", "listado-estaciones-completo.pickle")

with open(ruta_al_archivo, "rb") as f:
    estaciones = pickle.load(f)

print(estaciones)
# Out:
# {'11208': {'descripcion': 'vitoria/gasteiz', 'latitud': '42,8415284', 'longitud': '-2,6726651', 'dirección': 'plazuela de la estacion, 1', 'c.p.': '01005', 'poblacion': 'vitoria-gasteiz', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11212': {'descripcion': 'agurain/salvatierra de alava', 'latitud': '42,8464369', 'longitud': '-2,3892266', 'dirección': 'trebiño kalea, s/n', 'c.p.': '01200', 'poblacion': 'salvatierra/agurain', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11213': {'descripcion': 'araia', 'latitud': '42,8694713', 'longitud': '-2,3068018', 'dirección': 'calle estacion ferrocarril, s/n', 'c.p.': '01208', 'poblacion': 'arraia-maeztu', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11203': {'descripcion': 'manzanos', 'latitud': '42,7428754', 'longitud': '-2,8675305', 'dirección': 'rio zadorra kalea, s/n', 'c.p.': '01220', 'poblacion': 'ribera baja/erribera beitia', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11205': {'descripcion': 'nanclares-langraiz', 'latitud': '42,8162344', 'longitud': '-2,8049335', 'dirección': 'la estacion kalez, s/n', 'c.p.': '01230', 'poblacion': 'iruña oka/iruña de oca', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '11210': {'descripcion': 'alegria-dulantzi', 'latitud': '42,8488289', 'longitud': '-2,5145516', 'dirección': 'calle estacion ferrocarril, s/n', 'c.p.': '01240', 'poblacion': 'alegría-dulantzi', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '13104': {'descripcion': 'santa cruz de llodio', 'latitud': '43,132826', 'longitud': '-2,969878', 'dirección': 'poligono indrustrialdea, s/n', 'c.p.': '01400', 'poblacion': 'laudio/llodio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13106': {'descripcion': 'llodio', 'latitud': '43,14236', 'longitud': '-2,960654', 'dirección': 'jose matia kalea, s/n', 'c.p.': '01400', 'poblacion': 'laudio/llodio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13107': {'descripcion': 'areta', 'latitud': '43,145122', 'longitud': '-2,94342', 'dirección': 'estacion bidea, 4', 'c.p.': '01400', 'poblacion': 'laudio/llodio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13103': {'descripcion': 'luiaondo', 'latitud': '43,093579', 'longitud': '-2,999671', 'dirección': 'oloste kalea, s/n', 'c.p.': '01408', 'poblacion': 'ayala/aiara', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13101': {'descripcion': 'amurrio', 'latitud': '43,049155', 'longitud': '-3,001748', 'dirección': 'kalea dionisio aldama, 15', 'c.p.': '01470', 'poblacion': 'amurrio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13102': {'descripcion': 'salbio', 'latitud': '43,074147', 'longitud': '-2,999397', 'dirección': 'urrieta kalea, s/n', 'c.p.': '01470', 'poblacion': 'amurrio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13116': {'descripcion': 'iñarratxu', 'latitud': '43,035792', 'longitud': '-3,003896', 'dirección': 'saratxo entitatea, s/n', 'c.p.': '01470', 'poblacion': 'amurrio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '13121': {'descripcion': 'amurrio iparralde', 'latitud': '43,05771', 'longitud': '-2,996331', 'dirección': 'juan de aranoa kalea, s/n', 'c.p.': '01470', 'poblacion': 'amurrio', 'provincia': 'araba/álava', 'pais': 'españa', 'cercanias': 'si', 'feve': 'no'}, '60600': {'descripcion': 'albacete los llanos', 'latitud': '39,0002979', 'longitud': '-1,8487356', 'dirección': 'calle federico garcia lorca, 1', 'c.p.': '02001', 'poblacion': 'albacete', 'provincia': 'albacete', 'pais': 'españa', 'cercanias': 'no', 'feve': 'no'}, '60507': {'descripcion': 'la gineta', 'latitud': '39,1117194', 'longitud': '-2,000316', 'dirección': 'calle santa ana, ...

# %% [markdown]
# ## Ejercicios
#
# 1. Añade un método a la clase `Noticia` que permita almacenar en un archivo `.json` una Noticia cuya clave sea el id (el campo `@property` que implementaste al principio). Si ya existe, debería actualizarla.
